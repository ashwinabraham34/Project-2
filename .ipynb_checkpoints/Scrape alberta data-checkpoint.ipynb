# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path)

# %%
url = 'https://www.alberta.ca/stats/covid-19-alberta-statistics.htm'
browser.visit(url)
browser.click_link_by_partial_text('Data export')

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
table = soup.find('div', class_='dataTables_scrollBody')
table_rows = table.find_all('tr')

# %%
res = []
for x in table_rows:
    td = x.find_all('td')
    row = [x.text.strip() for x in td if x.text.strip()]
    if row:
        res.append(row)
df = pd.DataFrame(res, columns=["index1","Date Reported","Alberta Health Zone","Gender","Age Group","Case Status", "Case Type"])
df
# Out:
#                     index1 Date Reported Alberta Health Zone  Gender  \
# 0   2020-03-06\n2020-06-05          None                None    None
# 1                        1    2020-04-23        Calgary Zone  Female
# 2                        2    2020-04-21        Calgary Zone    Male
# 3                        3    2020-04-29          South Zone    Male
# 4                        4    2020-04-27        Calgary Zone    Male
# 5                        5    2020-04-09        Calgary Zone    Male
# 6                        6    2020-05-15        Calgary Zone    Male
# 7                        7    2020-03-25        Calgary Zone  Female
# 8                        8    2020-04-23        Calgary Zone  Female
# 9                        9    2020-03-25        Calgary Zone  Female
# 10                      10    2020-04-22        Calgary Zone  Female
# 11                      11    2020-05-22        Calgary Zone    Male
# 12                      12    2020-04-15          North Zone  Female
# 13                      13    2020-03-31       Edmonton Zone    Male
# 14                      14    2020-03-26        Calgary Zone  Female
# 15                      15    2020-03-25        Calgary Zone  Female
# 16                      16    2020-04-18        Calgary Zone  Female
# 17                      17    2020-04-30          South Zone    Male
# 18                      18    2020-04-30          South Zone  Female
# 19                      19    2020-04-18        Calgary Zone    Male
# 20                      20    2020-05-09          South Zone    Male
# 21                      21    2020-05-13        Calgary Zone    Male
# 22                      22    2020-04-22          South Zone    Male
# 23                      23    2020-04-21        Calgary Zone    Male
# 24                      24    2020-03-21        Calgary Zone  Female
# 25                      25    2020-04-17        Calgary Zone  Female
# 26                      26    2020-04-21        Calgary Zone    Male
# 27                      27    2020-04-18        Calgary Zone  Female
# 28                      28    2020-03-22        Calgary Zone  Female
# 29                      29    2020-03-16        Calgary Zone    Male
# 30                      30    2020-04-21        Calgary Zone    Male
# 31                      31    2020-04-28          South Zone    Male
# 32                      32    2020-03-19        Calgary Zone  Female
# 33                      33    2020-04-01        Calgary Zone  Female
# 34                      34    2020-04-28          South Zone    Male
# 35                      35    2020-04-29          South Zone  Female
# 36                      36    2020-04-30        Calgary Zone  Female
# 37                      37    2020-04-30          South Zone    Male
# 38                      38    2020-04-16        Calgary Zone    Male
# 39                      39    2020-05-30          North Zone  Female
# 40                      40    2020-04-19        Calgary Zone    Male
# 41                      41    2020-03-25        Calgary Zone  Female
# 42                      42    2020-04-18        Calgary Zone  Female
# 43                      43    2020-04-19        Calgary Zone  Female
# 44                      44    2020-04-25          South Zone    Male
# 45                      45    2020-04-09        Calgary Zone    Male
# 46                      46    2020-04-26        Calgary Zone  Female
# 47                      47    2020-05-14        Calgary Zone  Female
# 48                      48    2020-04-26        Calgary Zone  Female
# 49                      49    2020-04-14        Calgary Zone    Male
# 50                      50    2020-04-22        Calgary Zone    Male
#
#       Age Group Case Status  Case Type
# 0          None        None       None
# 1   40-49 years   Recovered  Confirmed
# 2     80+ years   Recovered  Confirmed
# 3   40-49 years   Recovered  Confirmed
# 4   50-59 years   Recovered  Confirmed
# 5   30-39 years   Recovered  Confirmed
# 6   40-49 years   Recovered  Confirmed
# 7   30-39 years   Recovered  Confirmed
# 8     80+ years   Recovered  Confirmed
# 9   20-29 years   Recovered  Confirmed
# 10  10-19 years   Recovered  Confirmed
# 11  50-59 years      Active  Confirmed
# 12    80+ years   Recovered  Confirmed
# 13  60-69 years   Recovered   Probable
# 14  30-39 years   Recovered   Probable
# 15  20-29 years   Recovered  Confirmed
# 16  10-19 years   Recovered  Confirmed
# 17  30-39 years   Recovered  Confirmed
# 18  10-19 years   Recovered  Confirmed
# 19  50-59 years   Recovered  Confirmed
# 20  20-29 years   Recovered  Confirmed
# 21  20-29 years   Recovered  Confirmed
# 22  60-69 years   Recovered  Confirmed
# 23  20-29 years   Recovered  Confirmed
# 24  30-39 years   Recovered  Confirmed
# 25    1-4 years   Recovered  Confirmed
# 26  40-49 years   Recovered  Confirmed
# 27  30-39 years   Recovered  Confirmed
# 28  50-59 years   Recovered  Confirmed
# 29    5-9 years   Recovered  Confirmed
# 30  30-39 years   Recovered  Confirmed
# 31  10-19 years   Recovered  Confirmed
# 32  50-59 years   Recovered  Confirmed
# 33  40-49 years   Recovered  Confirmed
# 34  10-19 years   Recovered  Confirmed
# 35  30-39 years   Recovered  Confirmed
# 36  20-29 years   Recovered  Confirmed
# 37  40-49 years   Recovered  Confirmed
# 38  30-39 years   Recovered  Confirmed
# 39    5-9 years      Active  Confirmed
# 40  60-69 years   Recovered  Confirmed
# 41    80+ years   Recovered  Confirmed
# 42  40-49 years   Recovered  Confirmed
# 43  20-29 years   Recovered  Confirmed
# 44  40-49 years   Recovered  Confirmed
# 45  30-39 years   Recovered  Confirmed
# 46  10-19 years   Recovered  Confirmed
# 47  30-39 years   Recovered  Confirmed
# 48  30-39 years   Recovered  Confirmed
# 49  40-49 years   Recovered  Confirmed
# 50  40-49 years   Recovered  Confirmed

# %%
try:
    browser.click_link_by_partial_text('next')
    table = soup.find('div', class_='dataTables_scrollBody')
    table_rows = table.find_all('tr')
    for x in table_rows:
    td = x.find_all('td')
    row = [x.text.strip() for x in td if x.text.strip()]
    if row:
        res.append(row)
except ElementDoesNotExist:

df = pd.DataFrame(res, columns=["index1","Date Reported","Alberta Health Zone","Gender","Age Group","Case Status", "Case Type"])
df
# Out:
#   File "<ipython-input-55-f09dcab1671c>", line 7
#     td = x.find_all('td')
#      ^
# IndentationError: expected an indented block
